# %%
# !pip install -r requirements.txt
import numpy as np
import matplotlib.pyplot as plt 
#!pip install -U ipykernel
# Out:
# Requirement already satisfied: appmode in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 1)) (0.8.0)
# Requirement already satisfied: numpy in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 3)) (1.18.5)
# Requirement already satisfied: scipy in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: ipywidgets in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 5)) (7.7.0)
# Requirement already satisfied: ipython>=8.0.1 in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 6)) (8.6.0)
# Requirement already satisfied: traits in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 7)) (6.3.2)
# Requirement already satisfied: matplotlib in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 8)) (3.5.2)
# Requirement already satisfied: sympy<=1.7.1 in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 9)) (1.6.1)
# Requirement already satisfied: k3d in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 10)) (2.14.5)
# Requirement already satisfied: ipympl in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 11)) (0.9.1)
# Requirement already satisfied: ipytree in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 12)) (0.2.1)
# Requirement already satisfied: shapely in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 13)) (1.8.5.post1)
# Requirement already satisfied: importlib_resources in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 14)) (5.8.0)
# Requirement already satisfied: traitsui==7.1.0 in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 15)) (7.1.0)
# Requirement already satisfied: xlrd in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 17)) (1.2.0)
# Requirement already satisfied: xlwt in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 18)) (1.3.0)
# Requirement already satisfied: xlsxwriter in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 19)) (1.2.9)
# Requirement already satisfied: selenium in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 20)) (4.6.0)
# Requirement already satisfied: bs4 in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 21)) (0.0.1)
# Requirement already satisfied: lxml in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 22)) (4.5.2)
# Requirement already satisfied: requests in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 23)) (2.24.0)
# Requirement already satisfied: geopandas in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 24)) (0.12.1)
# Requirement already satisfied: census in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 25)) (0.8.19)
# Requirement already satisfied: us in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 26)) (2.0.2)
# Requirement already satisfied: notebook in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 27)) (6.0.3)
# Requirement already satisfied: bumpversion==0.5.3 in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 28)) (0.5.3)
# Requirement already satisfied: wheel==0.29.0 in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 29)) (0.29.0)
# Processing c:\users\rob\appdata\local\pip\cache\wheels\a8\29\df\5ff22abd72fed59203ad8a9f4271de090fc02f605c5b7be6e5\watchdog-0.8.3-py3-none-any.whl
# Collecting flake8==2.6.0
#   Using cached flake8-2.6.0-py2.py3-none-any.whl (38 kB)
# Collecting tox==2.3.1
#   Using cached tox-2.3.1-py2.py3-none-any.whl (40 kB)
# Processing c:\users\rob\appdata\local\pip\cache\wheels\59\ca\90\be44c8c277782bca1ea861c13540262155168579ea1fced5eb\coverage-4.1-cp38-cp38-win_amd64.whl
# Collecting Sphinx==1.4.8
#   Using cached Sphinx-1.4.8-py2.py3-none-any.whl (1.6 MB)
# Collecting cryptography==1.7
#   Using cached cryptography-1.7.tar.gz (420 kB)
# Processing c:\users\rob\appdata\local\pip\cache\wheels\be\d7\52\2921bb6cfc62884c1abfaf54a2b105bba5aedc54567eda144d\pyyaml-3.11-cp38-cp38-win_amd64.whl
# Collecting Cython>=0.29.23
#   Using cached Cython-0.29.32-py2.py3-none-any.whl (986 kB)
# Collecting Pillow>=8.2.0
#   Using cached Pillow-9.3.0-cp38-cp38-win_amd64.whl (2.5 MB)
# Requirement already satisfied: click>=7.1.2 in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 39)) (7.1.2)
# Requirement already satisfied: cycler>=0.10.0 in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 40)) (0.10.0)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.4-cp38-cp38-win_amd64.whl (55 kB)
# Requirement already satisfied: numdifftools>=0.9.39 in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 42)) (0.9.39)
# Requirement already satisfied: openseespy in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 43)) (3.3.0.0)
# Requirement already satisfied: openseespywin in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 44)) (3.3.0.0)
# Requirement already satisfied: pandas in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 45)) (1.0.5)
# Requirement already satisfied: pyparsing in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 46)) (2.4.7)
# Requirement already satisfied: python-dateutil in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 47)) (2.8.1)
# Requirement already satisfied: quadprog==0.1.8 in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 48)) (0.1.8)
# Requirement already satisfied: setuptools in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 49)) (49.2.0.post20200714)
# Requirement already satisfied: six==1.15.0 in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 50)) (1.15.0)
# Collecting quadprog-wheel==0.1.11
#   Using cached quadprog_wheel-0.1.11-cp38-cp38-win_amd64.whl (80 kB)
# Requirement already satisfied: algopy==0.5.7 in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 52)) (0.5.7)
# Requirement already satisfied: colorama==0.4.5 in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 53)) (0.4.5)
# Collecting fonttools==4.34.4
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\Users\Rob\anaconda2020\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Rob\\AppData\\Local\\Temp\\pip-install-cue7n75n\\cryptography\\setup.py'"'"'; __file__='"'"'C:\\Users\\Rob\\AppData\\Local\\Temp\\pip-install-cue7n75n\\cryptography\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Rob\AppData\Local\Temp\pip-wheel-ipw7ipsd'
#        cwd: C:\Users\Rob\AppData\Local\Temp\pip-install-cue7n75n\cryptography\
#   Complete output (116 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.8
#   creating build\lib.win-amd64-3.8\cryptography
#   copying src\cryptography\exceptions.py -> build\lib.win-amd64-3.8\cryptography
#   copying src\cryptography\fernet.py -> build\lib.win-amd64-3.8\cryptography
#   copying src\cryptography\utils.py -> build\lib.win-amd64-3.8\cryptography
#   copying src\cryptography\__about__.py -> build\lib.win-amd64-3.8\cryptography
#   copying src\cryptography\__init__.py -> build\lib.win-amd64-3.8\cryptography
#   creating build\lib.win-amd64-3.8\cryptography\hazmat
#   copying src\cryptography\hazmat\__init__.py -> build\lib.win-amd64-3.8\cryptography\hazmat
#   creating build\lib.win-amd64-3.8\cryptography\x509
#   copying src\cryptography\x509\base.py -> build\lib.win-amd64-3.8\cryptography\x509
#   copying src\cryptography\x509\extensions.py -> build\lib.win-amd64-3.8\cryptography\x509
#   copying src\cryptography\x509\general_name.py -> build\lib.win-amd64-3.8\cryptography\x509
#   copying src\cryptography\x509\name.py -> build\lib.win-amd64-3.8\cryptography\x509
#   copying src\cryptography\x509\oid.py -> build\lib.win-amd64-3.8\cryptography\x509
#   copying src\cryptography\x509\__init__.py -> build\lib.win-amd64-3.8\cryptography\x509
#   creating build\lib.win-amd64-3.8\cryptography\hazmat\backends
#   copying src\cryptography\hazmat\backends\interfaces.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends
#   copying src\cryptography\hazmat\backends\multibackend.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends
#   copying src\cryptography\hazmat\backends\__init__.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends
#   creating build\lib.win-amd64-3.8\cryptography\hazmat\bindings
#   copying src\cryptography\hazmat\bindings\__init__.py -> build\lib.win-amd64-3.8\cryptography\hazmat\bindings
#   creating build\lib.win-amd64-3.8\cryptography\hazmat\primitives
#   copying src\cryptography\hazmat\primitives\cmac.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives
#   copying src\cryptography\hazmat\primitives\constant_time.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives
#   copying src\cryptography\hazmat\primitives\hashes.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives
#   copying src\cryptography\hazmat\primitives\hmac.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives
#   copying src\cryptography\hazmat\primitives\keywrap.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives
#   copying src\cryptography\hazmat\primitives\padding.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives
#   copying src\cryptography\hazmat\primitives\serialization.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives
#   copying src\cryptography\hazmat\primitives\__init__.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives
#   creating build\lib.win-amd64-3.8\cryptography\hazmat\backends\commoncrypto
#   copying src\cryptography\hazmat\backends\commoncrypto\backend.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\commoncrypto
#   copying src\cryptography\hazmat\backends\commoncrypto\ciphers.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\commoncrypto
#   copying src\cryptography\hazmat\backends\commoncrypto\hashes.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\commoncrypto
#   copying src\cryptography\hazmat\backends\commoncrypto\hmac.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\commoncrypto
#   copying src\cryptography\hazmat\backends\commoncrypto\__init__.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\commoncrypto
#   creating build\lib.win-amd64-3.8\cryptography\hazmat\backends\openssl
#   copying src\cryptography\hazmat\backends\openssl\backend.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\openssl
#   copying src\cryptography\hazmat\backends\openssl\ciphers.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\openssl
#   copying src\cryptography\hazmat\backends\openssl\cmac.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\openssl
#   copying src\cryptography\hazmat\backends\openssl\decode_asn1.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\openssl
#   copying src\cryptography\hazmat\backends\openssl\dh.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\openssl
#   copying src\cryptography\hazmat\backends\openssl\dsa.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\openssl
#   copying src\cryptography\hazmat\backends\openssl\ec.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\openssl
#   copying src\cryptography\hazmat\backends\openssl\encode_asn1.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\openssl
#   copying src\cryptography\hazmat\backends\openssl\hashes.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\openssl
#   copying src\cryptography\hazmat\backends\openssl\hmac.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\openssl
#   copying src\cryptography\hazmat\backends\openssl\rsa.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\openssl
#   copying src\cryptography\hazmat\backends\openssl\utils.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\openssl
#   copying src\cryptography\hazmat\backends\openssl\x509.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\openssl
#   copying src\cryptography\hazmat\backends\openssl\__init__.py -> build\lib.win-amd64-3.8\cryptography\hazmat\backends\openssl
#   creating build\lib.win-amd64-3.8\cryptography\hazmat\bindings\commoncrypto
#   copying src\cryptography\hazmat\bindings\commoncrypto\binding.py -> build\lib.win-amd64-3.8\cryptography\hazmat\bindings\commoncrypto
#   copying src\cryptography\hazmat\bindings\commoncrypto\__init__.py -> build\lib.win-amd64-3.8\cryptography\hazmat\bindings\commoncrypto
#   creating build\lib.win-amd64-3.8\cryptography\hazmat\bindings\openssl
#   copying src\cryptography\hazmat\bindings\openssl\binding.py -> build\lib.win-amd64-3.8\cryptography\hazmat\bindings\openssl
#   copying src\cryptography\hazmat\bindings\openssl\_conditional.py -> build\lib.win-amd64-3.8\cryptography\hazmat\bindings\openssl
#   copying src\cryptography\hazmat\bindings\openssl\__init__.py -> build\lib.win-amd64-3.8\cryptography\hazmat\bindings\openssl
#   creating build\lib.win-amd64-3.8\cryptography\hazmat\primitives\asymmetric
#   copying src\cryptography\hazmat\primitives\asymmetric\dh.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\asymmetric
#   copying src\cryptography\hazmat\primitives\asymmetric\dsa.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\asymmetric
#   copying src\cryptography\hazmat\primitives\asymmetric\ec.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\asymmetric
#   copying src\cryptography\hazmat\primitives\asymmetric\padding.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\asymmetric
#   copying src\cryptography\hazmat\primitives\asymmetric\rsa.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\asymmetric
#   copying src\cryptography\hazmat\primitives\asymmetric\utils.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\asymmetric
#   copying src\cryptography\hazmat\primitives\asymmetric\__init__.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\asymmetric
#   creating build\lib.win-amd64-3.8\cryptography\hazmat\primitives\ciphers
#   copying src\cryptography\hazmat\primitives\ciphers\algorithms.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\ciphers
#   copying src\cryptography\hazmat\primitives\ciphers\base.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\ciphers
#   copying src\cryptography\hazmat\primitives\ciphers\modes.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\ciphers
#   copying src\cryptography\hazmat\primitives\ciphers\__init__.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\ciphers
#   creating build\lib.win-amd64-3.8\cryptography\hazmat\primitives\interfaces
#   copying src\cryptography\hazmat\primitives\interfaces\__init__.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\interfaces
#   creating build\lib.win-amd64-3.8\cryptography\hazmat\primitives\kdf
#   copying src\cryptography\hazmat\primitives\kdf\concatkdf.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\kdf
#   copying src\cryptography\hazmat\primitives\kdf\hkdf.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\kdf
#   copying src\cryptography\hazmat\primitives\kdf\kbkdf.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\kdf
#   copying src\cryptography\hazmat\primitives\kdf\pbkdf2.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\kdf
#   copying src\cryptography\hazmat\primitives\kdf\scrypt.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\kdf
#   copying src\cryptography\hazmat\primitives\kdf\x963kdf.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\kdf
#   copying src\cryptography\hazmat\primitives\kdf\__init__.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\kdf
#   creating build\lib.win-amd64-3.8\cryptography\hazmat\primitives\twofactor
#   copying src\cryptography\hazmat\primitives\twofactor\hotp.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\twofactor
#   copying src\cryptography\hazmat\primitives\twofactor\totp.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\twofactor
#   copying src\cryptography\hazmat\primitives\twofactor\utils.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\twofactor
#   copying src\cryptography\hazmat\primitives\twofactor\__init__.py -> build\lib.win-amd64-3.8\cryptography\hazmat\primitives\twofactor
#   running egg_info
#   writing src\cryptography.egg-info\PKG-INFO
#   writing dependency_links to src\cryptography.egg-info\dependency_links.txt
#   writing entry points to src\cryptography.egg-info\entry_points.txt
#   writing requirements to src\cryptography.egg-info\requires.txt
#   writing top-level names to src\cryptography.egg-info\top_level.txt
#   reading manifest file 'src\cryptography.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   no previously-included directories found matching 'docs\_build'
#   warning: no previously-included files matching '*' found under directory 'vectors'
#   writing manifest file 'src\cryptography.egg-info\SOURCES.txt'
#   running build_ext
#   generating cffi module 'build\\temp.win-amd64-3.8\\Release\\_padding.c'
#   creating build\temp.win-amd64-3.8
#   creating build\temp.win-amd64-3.8\Release
#   generating cffi module 'build\\temp.win-amd64-3.8\\Release\\_constant_time.c'
#   generating cffi module 'build\\temp.win-amd64-3.8\\Release\\_openssl.c'
#   building '_openssl' extension
#   creating build\temp.win-amd64-3.8\Release\build
#   creating build\temp.win-amd64-3.8\Release\build\temp.win-amd64-3.8
#   creating build\temp.win-amd64-3.8\Release\build\temp.win-amd64-3.8\Release
#   C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.34.31933\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Ic:\Users\Rob\anaconda2020\include -Ic:\Users\Rob\anaconda2020\include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.34.31933\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.34.31933\ATLMFC\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22000.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22000.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22000.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22000.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22000.0\\cppwinrt" "-IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um" /Tcbuild\temp.win-amd64-3.8\Release\_openssl.c /Fobuild\temp.win-amd64-3.8\Release\build\temp.win-amd64-3.8\Release\_openssl.obj
#   _openssl.c
#   build\temp.win-amd64-3.8\Release\_openssl.c(541): fatal error C1083: Cannot open include file: 'openssl/opensslv.h': No such file or directory
#   error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2022\\BuildTools\\VC\\Tools\\MSVC\\14.34.31933\\bin\\HostX86\\x64\\cl.exe' failed with exit status 2
#   ----------------------------------------
#   ERROR: Failed building wheel for cryptography
# ERROR: spyder 4.1.4 requires pyqt5<5.13; python_version >= "3", which is not installed.
# ERROR: spyder 4.1.4 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# ERROR: pytest 5.4.3 has requirement pluggy<1.0,>=0.12, but you'll have pluggy 0.3.1 which is incompatible.
# ERROR: pyopenssl 19.1.0 has requirement cryptography>=2.8, but you'll have cryptography 1.7 which is incompatible.
# ERROR: pylint 2.5.3 has requirement mccabe<0.7,>=0.6, but you'll have mccabe 0.5.3 which is incompatible.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 5
#       3 import matplotlib.pyplot as plt
#       4 #!pip install -U ipykernel
# ----> 5 MPN.shape
#
# NameError: name 'MPN' is not defined
#   Using cached fonttools-4.34.4-py3-none-any.whl (944 kB)
# Requirement already satisfied: packaging==21.3 in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 55)) (21.3)
# Collecting patsy==0.5.2
#   Using cached patsy-0.5.2-py2.py3-none-any.whl (233 kB)
# Collecting statsmodels==0.13.2
#   Using cached statsmodels-0.13.2-cp38-cp38-win_amd64.whl (9.1 MB)
# Collecting anastruct
#   Using cached anastruct-1.2.0-py3-none-any.whl (69 kB)
# Requirement already satisfied: openpyxl in c:\users\rob\anaconda2020\lib\site-packages (from -r requirements.txt (line 59)) (3.0.4)
# Collecting bmcs-matmod
#   Using cached bmcs_matmod-0.0.9a0-py2.py3-none-any.whl (53 kB)
# Collecting bmcs_utils
#   Using cached bmcs_utils-0.0.31a0-py2.py3-none-any.whl (52 kB)
# Collecting bmcs_ibvpy
#   Using cached bmcs_ibvpy-0.0.24a0-py2.py3-none-any.whl (441 kB)
# Collecting bmcs_cross_section
#   Using cached bmcs_cross_section-0.0.54a0-py2.py3-none-any.whl (57 kB)
# Collecting bmcs_beam
#   Using cached bmcs_beam-0.0.17a0-py2.py3-none-any.whl (262 kB)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\rob\anaconda2020\lib\site-packages (from ipywidgets->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\rob\anaconda2020\lib\site-packages (from ipywidgets->-r requirements.txt (line 5)) (5.3.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\rob\anaconda2020\lib\site-packages (from ipywidgets->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\rob\anaconda2020\lib\site-packages (from ipywidgets->-r requirements.txt (line 5)) (4.3.3)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\rob\anaconda2020\lib\site-packages (from ipywidgets->-r requirements.txt (line 5)) (5.0.7)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in c:\users\rob\anaconda2020\lib\site-packages (from ipywidgets->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: stack-data in c:\users\rob\anaconda2020\lib\site-packages (from ipython>=8.0.1->-r requirements.txt (line 6)) (0.6.1)
# Requirement already satisfied: pickleshare in c:\users\rob\anaconda2020\lib\site-packages (from ipython>=8.0.1->-r requirements.txt (line 6)) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\rob\anaconda2020\lib\site-packages (from ipython>=8.0.1->-r requirements.txt (line 6)) (0.17.1)
# Requirement already satisfied: matplotlib-inline in c:\users\rob\anaconda2020\lib\site-packages (from ipython>=8.0.1->-r requirements.txt (line 6)) (0.1.6)
# Requirement already satisfied: decorator in c:\users\rob\anaconda2020\lib\site-packages (from ipython>=8.0.1->-r requirements.txt (line 6)) (4.4.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in c:\users\rob\anaconda2020\lib\site-packages (from ipython>=8.0.1->-r requirements.txt (line 6)) (3.0.5)
# Requirement already satisfied: backcall in c:\users\rob\anaconda2020\lib\site-packages (from ipython>=8.0.1->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\rob\anaconda2020\lib\site-packages (from ipython>=8.0.1->-r requirements.txt (line 6)) (2.6.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\rob\anaconda2020\lib\site-packages (from sympy<=1.7.1->-r requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: traittypes in c:\users\rob\anaconda2020\lib\site-packages (from k3d->-r requirements.txt (line 10)) (0.2.1)
# Requirement already satisfied: msgpack in c:\users\rob\anaconda2020\lib\site-packages (from k3d->-r requirements.txt (line 10)) (1.0.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in c:\users\rob\anaconda2020\lib\site-packages (from importlib_resources->-r requirements.txt (line 14)) (3.1.0)
# Requirement already satisfied: pyface>=7.1.0 in c:\users\rob\anaconda2020\lib\site-packages (from traitsui==7.1.0->-r requirements.txt (line 15)) (7.4.1)
# Requirement already satisfied: trio~=0.17 in c:\users\rob\anaconda2020\lib\site-packages (from selenium->-r requirements.txt (line 20)) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\rob\anaconda2020\lib\site-packages (from selenium->-r requirements.txt (line 20)) (1.26.12)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\rob\anaconda2020\lib\site-packages (from selenium->-r requirements.txt (line 20)) (2022.9.24)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\rob\anaconda2020\lib\site-packages (from selenium->-r requirements.txt (line 20)) (0.9.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\rob\anaconda2020\lib\site-packages (from bs4->-r requirements.txt (line 21)) (4.9.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\rob\anaconda2020\lib\site-packages (from requests->-r requirements.txt (line 23)) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\rob\anaconda2020\lib\site-packages (from requests->-r requirements.txt (line 23)) (3.0.4)
# Requirement already satisfied: pyproj>=2.6.1.post1 in c:\users\rob\anaconda2020\lib\site-packages (from geopandas->-r requirements.txt (line 24)) (3.4.0)
# Requirement already satisfied: fiona>=1.8 in c:\users\rob\anaconda2020\lib\site-packages (from geopandas->-r requirements.txt (line 24)) (1.8.22)
# Requirement already satisfied: jellyfish==0.6.1 in c:\users\rob\anaconda2020\lib\site-packages (from us->-r requirements.txt (line 26)) (0.6.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\rob\anaconda2020\lib\site-packages (from notebook->-r requirements.txt (line 27)) (6.1.6)
# Requirement already satisfied: nbconvert in c:\users\rob\anaconda2020\lib\site-packages (from notebook->-r requirements.txt (line 27)) (5.6.1)
# Requirement already satisfied: prometheus-client in c:\users\rob\anaconda2020\lib\site-packages (from notebook->-r requirements.txt (line 27)) (0.8.0)
# Requirement already satisfied: jinja2 in c:\users\rob\anaconda2020\lib\site-packages (from notebook->-r requirements.txt (line 27)) (2.11.2)
# Requirement already satisfied: tornado>=5.0 in c:\users\rob\anaconda2020\lib\site-packages (from notebook->-r requirements.txt (line 27)) (6.0.4)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\rob\anaconda2020\lib\site-packages (from notebook->-r requirements.txt (line 27)) (4.6.3)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\rob\anaconda2020\lib\site-packages (from notebook->-r requirements.txt (line 27)) (0.8.3)
# Requirement already satisfied: pyzmq>=17 in c:\users\rob\anaconda2020\lib\site-packages (from notebook->-r requirements.txt (line 27)) (19.0.1)
# Requirement already satisfied: Send2Trash in c:\users\rob\anaconda2020\lib\site-packages (from notebook->-r requirements.txt (line 27)) (1.5.0)
# Requirement already satisfied: argh>=0.24.1 in c:\users\rob\anaconda2020\lib\site-packages (from watchdog==0.8.3->-r requirements.txt (line 30)) (0.26.2)
# Requirement already satisfied: pathtools>=0.1.1 in c:\users\rob\anaconda2020\lib\site-packages (from watchdog==0.8.3->-r requirements.txt (line 30)) (0.1.2)
# Collecting mccabe<0.6,>=0.2.1
#   Using cached mccabe-0.5.3-py2.py3-none-any.whl (8.5 kB)
# Collecting pyflakes!=1.2.0,!=1.2.1,!=1.2.2,<1.3,>=0.8.1
#   Using cached pyflakes-1.2.3-py2.py3-none-any.whl (209 kB)
# Collecting pycodestyle<2.1,>=2.0
#   Using cached pycodestyle-2.0.0-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: py>=1.4.17 in c:\users\rob\anaconda2020\lib\site-packages (from tox==2.3.1->-r requirements.txt (line 32)) (1.9.0)
# Requirement already satisfied: virtualenv>=1.11.2 in c:\users\rob\anaconda2020\lib\site-packages (from tox==2.3.1->-r requirements.txt (line 32)) (20.16.3)
# Collecting pluggy<0.4.0,>=0.3.0
#   Using cached pluggy-0.3.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: imagesize in c:\users\rob\anaconda2020\lib\site-packages (from Sphinx==1.4.8->-r requirements.txt (line 34)) (1.2.0)
# Requirement already satisfied: docutils>=0.11 in c:\users\rob\anaconda2020\lib\site-packages (from Sphinx==1.4.8->-r requirements.txt (line 34)) (0.16)
# Requirement already satisfied: snowballstemmer>=1.1 in c:\users\rob\anaconda2020\lib\site-packages (from Sphinx==1.4.8->-r requirements.txt (line 34)) (2.0.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in c:\users\rob\anaconda2020\lib\site-packages (from Sphinx==1.4.8->-r requirements.txt (line 34)) (0.7.12)
# Requirement already satisfied: babel!=2.0,>=1.3 in c:\users\rob\anaconda2020\lib\site-packages (from Sphinx==1.4.8->-r requirements.txt (line 34)) (2.8.0)
# Collecting pyasn1>=0.1.8
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: cffi>=1.4.1 in c:\users\rob\anaconda2020\lib\site-packages (from cryptography==1.7->-r requirements.txt (line 35)) (1.14.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\rob\anaconda2020\lib\site-packages (from pandas->-r requirements.txt (line 45)) (2020.1)
# Requirement already satisfied: et-xmlfile in c:\users\rob\anaconda2020\lib\site-packages (from openpyxl->-r requirements.txt (line 59)) (1.0.1)
# Requirement already satisfied: jdcal in c:\users\rob\anaconda2020\lib\site-packages (from openpyxl->-r requirements.txt (line 59)) (1.4.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\rob\anaconda2020\lib\site-packages (from nbformat>=4.2.0->ipywidgets->-r requirements.txt (line 5)) (3.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\rob\anaconda2020\lib\site-packages (from stack-data->ipython>=8.0.1->-r requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\rob\anaconda2020\lib\site-packages (from stack-data->ipython>=8.0.1->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: pure-eval in c:\users\rob\anaconda2020\lib\site-packages (from stack-data->ipython>=8.0.1->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\rob\anaconda2020\lib\site-packages (from jedi>=0.16->ipython>=8.0.1->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\rob\anaconda2020\lib\site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=8.0.1->-r requirements.txt (line 6)) (0.2.5)
# Requirement already satisfied: sniffio in c:\users\rob\anaconda2020\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 20)) (1.3.0)
# Requirement already satisfied: outcome in c:\users\rob\anaconda2020\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 20)) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9; python_version < "3.11" in c:\users\rob\anaconda2020\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 20)) (1.0.4)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\rob\anaconda2020\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 20)) (19.3.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\rob\anaconda2020\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 20)) (1.10)
# Requirement already satisfied: sortedcontainers in c:\users\rob\anaconda2020\lib\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 20)) (2.2.2)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6; extra == "socks" in c:\users\rob\anaconda2020\lib\site-packages (from urllib3[socks]~=1.26->selenium->-r requirements.txt (line 20)) (1.7.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\rob\anaconda2020\lib\site-packages (from trio-websocket~=0.9->selenium->-r requirements.txt (line 20)) (1.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rob\anaconda2020\lib\site-packages (from beautifulsoup4->bs4->-r requirements.txt (line 21)) (2.0.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\rob\anaconda2020\lib\site-packages (from fiona>=1.8->geopandas->-r requirements.txt (line 24)) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\rob\anaconda2020\lib\site-packages (from fiona>=1.8->geopandas->-r requirements.txt (line 24)) (1.1.1)
# Requirement already satisfied: munch in c:\users\rob\anaconda2020\lib\site-packages (from fiona>=1.8->geopandas->-r requirements.txt (line 24)) (2.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\rob\anaconda2020\lib\site-packages (from nbconvert->notebook->-r requirements.txt (line 27)) (0.3)
# Requirement already satisfied: testpath in c:\users\rob\anaconda2020\lib\site-packages (from nbconvert->notebook->-r requirements.txt (line 27)) (0.4.4)
# Requirement already satisfied: defusedxml in c:\users\rob\anaconda2020\lib\site-packages (from nbconvert->notebook->-r requirements.txt (line 27)) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\rob\anaconda2020\lib\site-packages (from nbconvert->notebook->-r requirements.txt (line 27)) (1.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\rob\anaconda2020\lib\site-packages (from nbconvert->notebook->-r requirements.txt (line 27)) (0.8.4)
# Requirement already satisfied: bleach in c:\users\rob\anaconda2020\lib\site-packages (from nbconvert->notebook->-r requirements.txt (line 27)) (3.1.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\rob\anaconda2020\lib\site-packages (from jinja2->notebook->-r requirements.txt (line 27)) (1.1.1)
# ERROR: paramiko 2.7.1 has requirement cryptography>=2.5, but you'll have cryptography 1.7 which is incompatible.
# ERROR: numpydoc 1.1.0 has requirement sphinx>=1.6.5, but you'll have sphinx 1.4.8 which is incompatible.
# ERROR: conda-verify 3.4.2 has requirement pyyaml>=3.12, but you'll have pyyaml 3.11 which is incompatible.
# ERROR: autopep8 1.5.3 has requirement pycodestyle>=2.6.0, but you'll have pycodestyle 2.0.0 which is incompatible.
# ERROR: anaconda-client 1.7.2 has requirement PyYAML>=3.12, but you'll have pyyaml 3.11 which is incompatible.
# ERROR: Cannot uninstall 'PyYAML'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\rob\anaconda2020\lib\site-packages (from jupyter-core>=4.6.1->notebook->-r requirements.txt (line 27)) (227)
# Requirement already satisfied: platformdirs<3,>=2.4 in c:\users\rob\anaconda2020\lib\site-packages (from virtualenv>=1.11.2->tox==2.3.1->-r requirements.txt (line 32)) (2.5.2)
# Requirement already satisfied: distlib<1,>=0.3.5 in c:\users\rob\anaconda2020\lib\site-packages (from virtualenv>=1.11.2->tox==2.3.1->-r requirements.txt (line 32)) (0.3.5)
# Requirement already satisfied: filelock<4,>=3.4.1 in c:\users\rob\anaconda2020\lib\site-packages (from virtualenv>=1.11.2->tox==2.3.1->-r requirements.txt (line 32)) (3.7.1)
# Requirement already satisfied: pycparser in c:\users\rob\anaconda2020\lib\site-packages (from cffi>=1.4.1->cryptography==1.7->-r requirements.txt (line 35)) (2.20)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\rob\anaconda2020\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->-r requirements.txt (line 5)) (0.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\rob\anaconda2020\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium->-r requirements.txt (line 20)) (0.14.0)
# Requirement already satisfied: webencodings in c:\users\rob\anaconda2020\lib\site-packages (from bleach->nbconvert->notebook->-r requirements.txt (line 27)) (0.5.1)
# Building wheels for collected packages: cryptography
#   Building wheel for cryptography (setup.py): started
#   Building wheel for cryptography (setup.py): finished with status 'error'
#   Running setup.py clean for cryptography
# Failed to build cryptography
# Installing collected packages: PyYAML, watchdog, mccabe, pyflakes, pycodestyle, flake8, pluggy, tox, coverage, Sphinx, pyasn1, cryptography, Cython, Pillow, kiwisolver, quadprog-wheel, fonttools, patsy, statsmodels, anastruct, bmcs-matmod, bmcs-utils, bmcs-ibvpy, bmcs-cross-section, bmcs-beam
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 5.3.1

# %%
MPN.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 MPN.shape
#
# NameError: name 'MPN' is not defined

# %%
split=True
n_dim = 2 #number of dims in domain 
n_mp = 360 #number of microplanes in interpolation 
n_steps = 1000 #solver steps 
#ratio=step of defining actual domain
delta = np.identity(n_dim) #Kronecker δij
epsilon_11=np.linspace(0,0.01,n_steps)#define evenly the lin space from 0 to 0.01 with n_steps
#0.01 optional or otherwise raises DeprecationWarning when num cannot be safely interpreted as an integer
epsilon_ij=np.zeros((len(epsilon_11,),n_dim,n_dim))#creation of the finite 2d space
#epsilon_ijk=np.zeros((len(epsilon_11,),n_dim,n_dim,n_dim))
epsilon_ij[:,0,0]=epsilon_11 #reshape,arrange,apprehend 
#epsilon_ij[:,0,0,0]=epsilon_11
e1=np.array([1,0,0])
e2=np.array([0,1,0])
e3=np.array([0,0,1])

# %%
class IntegScheme():
    #n_mp=360
    alpha_list = np.linspace(0,2*np.pi,n_mp)#polar angle dom
    MPN = np.array([[np.cos(alpha),np.sin(alpha)] for alpha in alpha_list ])
    #alpha=float val?
    #weights of each microplane
    if n_dim==2:
        MPW = np.ones(n_mp) / n_mp * 2 
    elif n_dim==3:
        MPW = np.ones(n_mp) / n_mp * 6
    else: 
        print("ENTER NUMBER OF DIMS")
    
    MPM = np.zeros_like(MPN)

    delta= np.identity(n_dim) #should be already set?
    MPNN_nij = np.einsum('ni,nj -> nij', MPN,MPN)
    MPTT_nijr = 0.5*(np.einsum('ni,jr -> nijr',MPN,delta)
                    +np.einsum('nj,ir ->njir',MPN,delta)
                    -2*np.einsum('ni,nj,nr ->nijr',MPN,MPN,MPN))
    NPM=np.zeros_like(MPN)
    #attempt to create MPTM and MPTL instead ij sumbfor card coords
    lengthm=0.0
    while lengthm==0 :# DO WHILE (lengthm .lt. epsilon(lengthm)
    #calcdummy=MPN.shape
        randomvec=np.random.rand_like(MPN)
        MPTM_nijm=randomvec-np.dot(MPN,randomvec)*MPN
        lengthm=np.sqrt(MPTM_nij,MPTM_nij)
    MPTM_nij=MPTM_nijm/lengthm
    MPTL_ij=np.cross(MPTM_nij,MPNN_nij)
    


    #MPTM= np.einsum('nij,)
    #MPTL=MPNN_nij-MPNV
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 class IntegScheme():
#       2     #n_mp=360
#       3     alpha_list = np.linspace(0,2*np.pi,n_mp)#polar angle dom
#       4     MPN = np.array([[np.cos(alpha),np.sin(alpha)] for alpha in alpha_list ])
#
# Cell In [4], line 26, in IntegScheme()
#      23 lengthm=0.0
#      24 while lengthm==0 :# DO WHILE (lengthm .lt. epsilon(lengthm)
#      25 #calcdummy=MPN.shape
# ---> 26     randomvec=np.random.rand(MPN.shape)
#      27     MPTM_nijm=randomvec-np.dot(MPN,randomvec)*MPN
#      28     lengthm=np.sqrt(MPTM_nij,MPTM_nij)
#
# File mtrand.pyx:1154, in numpy.random.mtrand.RandomState.rand()
#
# File mtrand.pyx:420, in numpy.random.mtrand.RandomState.random_sample()
#
# File _common.pyx:256, in numpy.random._common.double_fill()
#
# TypeError: 'tuple' object cannot be interpreted as an integer

# %%
#for the creation of m&l we need a 3dlinspace apriori with set e1 to get the projection ?
#normal strain vector for each microplane
e_N = np.einsum('nij,...ij->...n',IntegScheme.MPNN_nij,epsilon_ij)
MPTT_ijr =  IntegScheme.MPTT_nijr 
e_T_r=np.einsum('nija,...ij->...na',MPTT_ijr,epsilon_ij)
e_V=np.identity(len())
e_D=e_N -e_V
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [22], line 6
#       4 MPTT_ijr =  IntegScheme.MPTT_nijr
#       5 e_T_r=np.einsum('nija,...ij->...na',MPTT_ijr,epsilon_ij)
# ----> 6 e_V=np.einsum('vij,...ij ->v',IntegScheme.MPNV,epsilon_ij)
#       7 e_D=np.einsum('dij,...ij ->d',IntegScheme.MPND,epsilon_ij)
#
# File <__array_function__ internals>:5, in einsum(*args, **kwargs)
#
# File c:\Users\Rob\anaconda2020\lib\site-packages\numpy\core\einsumfunc.py:1356, in einsum(*operands, **kwargs)
#    1354 # If no optimization, run pure einsum
#    1355 if optimize_arg is False:
# -> 1356     return c_einsum(*operands, **kwargs)
#    1358 valid_einsum_kwargs = ['out', 'dtype', 'order', 'casting']
#    1359 einsum_kwargs = {k: v for (k, v) in kwargs.items() if
#    1360                  k in valid_einsum_kwargs}
#
# ValueError: einstein sum subscripts string contains too many subscripts for operand 0

# %%
# %matplotlib widget
cm = 1 / 2.54  # centimeters in inches
plt.figure(figsize=(20*cm, 10*cm))
rads = np.arange(0, (2 * np.pi), (2 * np.pi) / n_mp)
plt.subplot(121, projection='polar')#subplot like matlab sets a matrix of plots but without setting ann array just the xyp where p position 
#plt.subplot(131 , projection='polar')
plt.plot(rads, e_N[-1, :], 'k')
plt.ylim(-1.5 * np.max(np.abs(e_N)),
                 1.5 * np.max(np.abs(e_N)))
plt.title(r'$ε_N$', fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=25)

plt.subplot(132, projection='polar')
plt.plot(rads, e_D[-1, :], 'k')
plt.ylim(-1.5 * np.max(np.abs(e_N)),
                 1.5 * np.max(np.abs(e_N)))
plt.title(r'$\varepsilon_D$', fontsize=25)

plt.tick_params(axis='both', which='major', labelsize=25)
plt.subplot(133, projection='polar')
plt.plot(rads, np.linalg.norm(e_T_r[-1, :],axis=-1), 'k')
plt.title(r'$ε_T$', fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=25)


plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#ELASTICITY CALCS
E_modulus =44800
n_poisson = 0.18
#issuewith if does not exit properly
if n_poisson <=-1 and n_poisson>=0.25 : 
    K_ =
    G =
else:
    K_1=
    G_1=0
    K_11 = K_+K_1
    G_11 = G+G_1
    n_pseudopoisson=(3*K_*(1+G/G_1)-2*G)/(6*K_*(1+G/G_1)+2*G)
E_N = E_modulus/(1-2*n_poisson)
E_T = E_N*((1-4*n_poisson)/(1+n_poisson))
E_V= E_modulus/(1-2*n_poisson)
xo=
E_D=5*E/((16+n_poisson)*(2+3*n_poisson))
E_N = K_/3
E_N = 70000 # [MPa]
E_T = 6700
from IPython.display import Latex

# %%
tryout =np.array([[1,2],[3,4]])
someproduct=np.einsum('nil,nlj -> nij',delta,tryout)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [13], line 2
#       1 tryout =np.array([[1,2],[3,4]])
# ----> 2 someproduct=np.einsum('nil,nlj -> nij',delta,tryout)
#
# File <__array_function__ internals>:5, in einsum(*args, **kwargs)
#
# File c:\Users\Rob\anaconda2020\lib\site-packages\numpy\core\einsumfunc.py:1356, in einsum(*operands, **kwargs)
#    1354 # If no optimization, run pure einsum
#    1355 if optimize_arg is False:
# -> 1356     return c_einsum(*operands, **kwargs)
#    1358 valid_einsum_kwargs = ['out', 'dtype', 'order', 'casting']
#    1359 einsum_kwargs = {k: v for (k, v) in kwargs.items() if
#    1360                  k in valid_einsum_kwargs}
#
# ValueError: einstein sum subscripts string contains too many subscripts for operand 0

# %%
s_N = E_N * e_N
s_V = E_V * e_V
s_D = E_D * e_D
s_T_r = E_T * e_T_r
########SIGMA=V/D twig plot 131 132 133 
# %matplotlib widget
cm = 1 / 2.54  # centimeters in inches
plt.figure(figsize=(30*cm, 15*cm))
rads = np.arange(0, (2 * np.pi), (2 * np.pi) / n_mp)
plt.subplot(121, projection='polar')
plt.plot(rads, s_N[-1, :], 'k')
plt.title(r'$\sigma_N$', fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=25)

plt.subplot(122, projection='polar')
plt.plot(rads, np.linalg.norm(s_T_r[-1, :],axis=-1), 'k')
plt.title(r'$\sigma_T$', fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=25)


plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
microplane = 45 #46°
cm = 1 / 2.54  # centimeters in inches
plt.figure(figsize=(30*cm, 15*cm))
plt.subplot(121)
plt.plot(e_N[:, microplane], s_N[:, microplane], 'k')
plt.title(r'$\sigma_N$', fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=25)

plt.subplot(122)
plt.plot(np.linalg.norm(e_T_r[:, microplane],axis=-1), np.linalg.norm(s_T_r[:, microplane],axis=-1), 'k')
plt.title(r'$\sigma_T$', fontsize=25)
plt.tick_params(axis='both', which='major', labelsize=25)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sigma_ij = (
                np.einsum('n,...n,na,nb->...ab',
                          IntegScheme.MPW, s_N, IntegScheme.MPN, IntegScheme.MPN) +
                0.5 * (
                        np.einsum('n,...nf,na,fb->...ab',
                                  IntegScheme.MPW, s_T_r, IntegScheme.MPN, delta) +
                        np.einsum('n,...nf,nb,fa->...ab',
                                  IntegScheme.MPW, s_T_r, IntegScheme.MPN, delta)
                )
        )

#with split 
sigma_ij= (np.einsum('v,....v,ij',s_V,delta)+np.einsum('d,...d,na,nb->...ab',
                          IntegScheme.MPW, s_N, IntegScheme.MPN, IntegScheme.MPN) +
                0.5 * (
                        np.einsum('n,...nf,na,fb->...ab',
                                  IntegScheme.MPW, s_T_r, IntegScheme.MPN, delta) +
                        np.einsum('n,...nf,nb,fa->...ab',
                                  IntegScheme.MPW, s_T_r, IntegScheme.MPN, delta)
                )
        )

# %%
class IntegScheme():
    #n_mp=360
    alpha_list = np.linspace(0,2*np.pi,n_mp)#polar angle dom
    MPN = np.array([[np.cos(alpha),np.sin(alpha)] for alpha in alpha_list ])
    #alpha=float val?
    #weights of each microplane
    #if n_dim==2:
    MPW = np.ones(n_mp) / n_mp * 2
    #elif n_dim==3:
     #       MPW = np.ones(n_mp) / n_mp * 6
    #else: 
     #       print("ENTER NUMBER OF DIMS")
    delta= np.identity(n_dim) #should be already set?
    MPNN_nij = np.einsum('ni,nj -> nij', MPN,MPN)
    MPTT_nijr = 0.5*(np.einsum('ni,jr -> nijr',MPN,delta)
                    +np.einsum('nj,ir ->njir',MPN,delta)
                    -2*np.einsum('ni,nj,nr ->nijr',MPN,MPN,MPN))
    MPNV= np.diag(MPN)
    MPND=MPNN_nij-MPNV

# %%
#ALG0
f_c0dot=
f_cdot=
gama_0=
k_1=#παρονομαστης κ εκθετικος παρονομαστης+ * sv bound  sd bound
k_4=#adding to a
k_3=#v bound * 
k_5=#just in a 
c_5=#in #bita 2 
c_6=#in bita 3 as the incl of bita to gama 1  
c_7=#in bita 2           
c_8=#in  bita 3 as b const ax+b
c_9=#in gama 1 
c_13=#in EN update 
c_20=#exp in a 
c_21=#lowball val in a 
bita_1=
bita_2=#s_d bound 
bita_3=#s_d bound
E_D0=E_D
gama_0=f_c0dot/E_D0+f_cdot/E_D
e_V0=e_V
s_N0=s_N
##########################################################
1
##########################################################
de_v=np.einsum('ij,ij',de_ij)/n_dim
de_ij= np.eye(epsilon_11,n_dim)#for sure wrong just to continue with the script 
de_n=np.einsum('nij,ij,->n',IntegScheme.MPNN_nij,de_ij)
de_m=
de_l=
i=0
###########################################################
2
###########################################################
y
de_v=np.einsum('ij,ij',de_ij)/n_dim
e_V=e_V+de_v
e_elastic=(s_V/E_N)
#principal stresses class!2 and 3d just from a mech book
s1=

###########################################################
3
###########################################################
a=(k_5/(1+min(-s_V,c21)/E_N))*((emin-emax)/k_1)**(c_20)+k_4
s_V_bound=-E_V*k_1*k_3*np.exp(-e_V/(k1*a))
###########################################################
4
###########################################################
de_d=de_n-de_v
e_D0=e_N-e_V0
e_D=e_D0+de_d
gama_1=np.exp(gama_0)*np.tanh*(c_9*(-e_V)/k_1)
bita_2=c_5*gama_1+c_7
bita_3=c_6*gama_1+c_8
s_D_bound=E_D*k_1*bita_3/(1+6((-e_D)/k_1*bita_2)**2)
###########################################################
e_N=e_D+e_V
s_N = E_N * e_N
s_V = E_V * e_V
s_D = E_D * e_D
s_T_r = E_T * e_T_r
e_0Nplus=max(e_N)
e_0Nminus=min(e_N)
E_N0=e/(1-2*n_poisson)
if s_N0>=0#np.zero_like(s_N)
    EN=E_N0*np.exp(-c_13*e_0Nplus)*
